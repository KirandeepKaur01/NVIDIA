# %% [markdown]
# Building a Brain in 10 minutes

# %% [markdown]
# Artificial neural network were developed to mimic the learning capabilities of humans and animals.
# Computers and machine learning libraries have evolved to where we can replicate many days of experimentation in just few minutes. How, A neural network have improved over the years and the biological inspiration behind it.
# Tensor flow , an open-source machine learning popular in industry . There is a GPU for computation.

# %%
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# []

# %% [markdown]
# gpu were orginally designed for the significant amount of matrix mathematics used when rendering computer graphics. Neural networks also require a significant amount of matrix multiplication, making GPUs a good fit when building them.

# %% [markdown]
# Data image classification with computer vision. Specifically, we will try to classify articles of clothing from the fashion MNIST
# Neural Network attempt to copy the human learning technique, Trial and Error. We will create a digital flashcards. Our artificial brains will attempt to guess what kind of cloths we are showing it with a flaskcard, then we will give it the answer, helping the computer learn from its success and mistakes.
# just the student quizzed the test their understanding, we will set aside a portion of our data to quiz our neural network s to make sure they understand the concepts we're trying to teach them, as opposed to them memorizing the answer to their study question. For trivia, memorization might be an acceptable strategy, but for skills, like adding number, memorization won.t get our models very far.
# The study data is often called the training. dataset and the quiz data is often called the validation dataset. As fashion MNIST is popular dataset , it is already included in tensorflow library.

# %%
fashion_mnist =tf.keras.datasets.fashion_mnist
(train_images, train_labels),(valid_images, valid_labels) = fashion_mnist.load_data()

# %%
#Let;s start with our train_images and train_labels.train_images are like the question on our flashcards

# %%
import matplotlib.pyplot as plt
data_idx =42
plt.figure()
plt.imshow(train_images[data_idx],cmap='gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt
data_idx =9
plt.figure()
plt.imshow(train_images[data_idx],cmap='gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt
data_idx = 4
plt.figure()
plt.imshow(train_images[data_idx],cmap='gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_labels[data_idx]
# Out:
# 0

# %% [markdown]
# What would you classify this as? To make it easier, here are the ten categories it could be:
#
# | Label | Description |
# | --- | --- |
# | 0 | T-shirt/top |
# | 1 | Trouser |
# | 2 | Pullover |
# | 3 | Dress |
# | 4 | Coat |
# | 5 | Sandal |
# | 6 | Shirt |
# | 7 | Sneaker |
# | 8 | Bag |
# | 9 | Ankle boot |
#
# Have an answer? Run the following code cell to see if you were correct:

# %%
import matplotlib.pyplot as plt

# The question number to quiz with. Feel free to change up to 9999.
data_idx = 6174

plt.figure()
plt.imshow(valid_images[data_idx], cmap='gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %%
import matplotlib.pyplot as plt
data_idx = 6147
plt.figure()
plt.imshow(valid_images[data_idx],cmap='gray')
plt.colorbar()
plt.grid(False)
plt.show()

# %%
# Assuming 'valid_labels' is part of a dataset, you'll need to load it.
# Here's an example using a hypothetical dataset:
from sklearn.model_selection import train_test_split
# !pip install scikit-learn

# Assuming 'images' and 'labels' are your original data
# Replace 'images' and 'labels' with your actual data variables
# train_images, valid_images, train_labels, valid_labels = train_test_split(
#     images, labels, test_size=0.2, random_state=42
# )

# Example: Assuming you have loaded your data into 'images' and 'labels'
# and want a 20% validation split:
# train_images, valid_images, train_labels, valid_labels = train_test_split(images, labels, test_size=0.2, random_state=42)


# Then you can access it:
# valid_labels[data_idx] # Now this should work after defining valid_labels

# %%
valid_labels[data_idx]
# Out:
# 5
